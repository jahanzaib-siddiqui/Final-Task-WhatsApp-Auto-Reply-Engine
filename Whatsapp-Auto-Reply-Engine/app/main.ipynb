# %%
from fastapi import FastAPI
from pydantic import BaseModel

from chatbot_engine import AutoReplyEngine


app = FastAPI(
    title="NitroXhift WhatsApp Auto-Reply Engine"
)


engine = AutoReplyEngine(
    "../data/faq_dataset.csv"
)


class MessageRequest(BaseModel):

    message: str


@app.get("/")
def home():

    return {
        "message":
        "NitroXhift WhatsApp Auto-Reply Engine is running"
    }


@app.post("/reply")
def get_reply(request: MessageRequest):

    result = engine.get_response(
        request.message
    )

    return result
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 4
#       1 from fastapi import FastAPI
#       2 from pydantic import BaseModel
# ----> 4 from chatbot_engine import AutoReplyEngine
#       7 app = FastAPI(
#       8     title="NitroXhift WhatsApp Auto-Reply Engine"
#       9 )
#      12 engine = AutoReplyEngine(
#      13     "../data/faq_dataset.csv"
#      14 )
#
# ModuleNotFoundError: No module named 'chatbot_engine'
